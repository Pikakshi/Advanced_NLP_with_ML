# %% [markdown]
# # Machine Learning with Python ... contd

# %% [markdown]
# # Supervised Learning: Regression

# %% [markdown]
# # 1. Problem Defintion
#
# Regression problem for *Product Sales Prediction* using an [advertising dataset](http://faculty.marshall.usc.edu/gareth-james/ISL/data.html). The dataset has the following features:
#
# - TV: advertising dollars spent on TV for a single product in a given market (in thousands of dollars)
# - Radio: advertising dollars spent on Radio
# - Newspaper: advertising dollars spent on Newspaper
#
# --> n = 3, m = 200 training examples
# - Target variable is continous valued which is why this is a **regression problem**.

# %% [markdown]
# # 2. Load Data
# ## 2.1 Importing Python Libraries

# %%
import sys
import scipy
import numpy
import matplotlib
import pandas as pd
# scikit-learn
import sklearn

# %% [markdown]
# If using Anaconda, pandas, numpy, scipy are included in *scikit-learn*
#
# ## 2.2 Load dataset
# Loading dataset as a Data Frame using **Pandas**

# %%
url = "data/Advertising.csv"
dataset = pd.read_csv(url, index_col=0)  #read csv file of the dataset
dataset.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# ## 2.2 Summarize Data

# %%
#shape of data
print(dataset.shape)

#display first 5 rows
print(dataset.head(5))

#display the last 5 rows
print(dataset.tail(5))

#print statistical summary
print(dataset.describe())

# %% [markdown]
# ## 2.3 Visualising Data
#
# **Seaborn**: Python library for statistical data visualization built on top of Matplotlib

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
sns.pairplot(dataset, diag_kind = 'kde')

# %%
# allow plots to appear within the notebook
# %matplotlib inline

# visualize the relationship between the features and the response using scatterplots
sns.pairplot(dataset, x_vars=['TV','radio','newspaper'], y_vars='sales', size=7, aspect=0.7, kind='reg')

# %% [markdown]
# More information about Data Visualisation in Python using *matplotlib, pandas* and *seaborn* can be found [here](https://towardsdatascience.com/introduction-to-data-visualization-in-python-89a54c97fbed).

# %% [markdown]
# ## 3. Evaluating Algorithms
#
# - Features and target variable are separate objects
# - Features and target variable should be **NumPy arrays**

# %%
array = dataset.values
X = array[:,0:3] #store feature matrix in "X"
y = array[:,3] #store target vector in "y"

print(X.shape)
print(y.shape)

# %% [markdown]
# ### Splitting X and y into training and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

# %% [markdown]
# ### Training the model on the training set
#
# __Linear Regression__

# %%
#import model
from sklearn.linear_model import LinearRegression

#instantiate the model
logreg = LinearRegression()

#fit the model with data
logreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## 4. Make Predictions

# %%
y_pred = logreg.predict(X_test)

# %% [markdown]
# ### Evaluation Metrics:
#
# For Regression problems, the following evaluation metrics can be used:
#
# - Mean Absolute Error (MAE) is the mean of the absolute value of the errors
# - Mean Squared Error (MSE) is the mean of the squared errors
# - Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors

# %%
from sklearn import metrics
import numpy as np
print(metrics.mean_absolute_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
